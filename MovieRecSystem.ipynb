# %%
import pandas as pd
import re

# %%
movies = pd.read_csv("movies.csv")
ratings = pd.read_csv("ratings.csv")
tags = pd.read_csv("tags.csv")
def clean_title (title):
  return re.sub ("[^a-zA-Z0-9 ]", "", title)

# %%
movies["clean_title"] = movies["title"].apply(clean_title)

movies["genres_clean"] = movies["genres"].str.replace("|", " ", regex=False)

movies["features"] = movies["clean_title"] + " " + (movies["genres_clean"] + "") * 3

# %%
movies
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres  \
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# 4                                          Comedy
# ...                                           ...
# 9737              Action|Animation|Comedy|Fantasy
# 9738                     Animation|Comedy|Fantasy
# 9739                                        Drama
# 9740                             Action|Animation
# 9741                                       Comedy
#
#                                  clean_title  \
# 0                             Toy Story 1995
# 1                               Jumanji 1995
# 2                      Grumpier Old Men 1995
# 3                     Waiting to Exhale 1995
# 4           Father of the Bride Part II 1995
# ...                                      ...
# 9737  Black Butler Book of the Atlantic 2017
# 9738               No Game No Life Zero 2017
# 9739                              Flint 2017
# 9740        Bungo Stray Dogs Dead Apple 2018
# 9741        Andrew Dice Clay Dice Rules 1991
#
#                                      genres_clean  \
# 0     Adventure Animation Children Comedy Fantasy
# 1                      Adventure Children Fantasy
# 2                                  Comedy Romance
# 3                            Comedy Drama Romance
# 4                                          Comedy
# ...                                           ...
# 9737              Action Animation Comedy Fantasy
# 9738                     Animation Comedy Fantasy
# 9739                                        Drama
# 9740                             Action Animation
# 9741                                       Comedy
#
#                                                features
# 0     Toy Story 1995 Adventure Animation Children Co...
# 1     Jumanji 1995 Adventure Children FantasyAdventu...
# 2     Grumpier Old Men 1995 Comedy RomanceComedy Rom...
# 3     Waiting to Exhale 1995 Comedy Drama RomanceCom...
# 4     Father of the Bride Part II 1995 ComedyComedyC...
# ...                                                 ...
# 9737  Black Butler Book of the Atlantic 2017 Action ...
# 9738  No Game No Life Zero 2017 Animation Comedy Fan...
# 9739                         Flint 2017 DramaDramaDrama
# 9740  Bungo Stray Dogs Dead Apple 2018 Action Animat...
# 9741  Andrew Dice Clay Dice Rules 1991 ComedyComedyC...
#
# [9742 rows x 6 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(ngram_range=(1,2))


movies["genres_clean"] = movies["genres"].str.replace("|", " ", regex=False)
movies["features"] = movies["clean_title"] + " " + movies["genres_clean"]

tfidf = vectorizer.fit_transform(movies["features"])

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
def title_search(title):
#title = " Toy Story (1995) "
  title = clean_title(title)
  query_vec = vectorizer.transform([title])
  similarity = cosine_similarity(query_vec, tfidf).flatten()
  indices = np.argpartition(similarity, -3)[-3:]
  results = movies.iloc[indices][::-1]
  #print(indices)
  return results

# %%
import ipywidgets as widgets
from IPython.display import display

movie_input = widgets.Text(
    value=' ',
    description='Movie Title:',
    disabled=False
)
movie_list = widgets.Output()

def on_type(data):
    with movie_list:
        movie_list.clear_output()
        title = data["new"]
        display(title_search(title))

movie_input.observe(on_type, names='value')


display(movie_input, movie_list)
# Out:
# Text(value=' ', description='Movie Title:')
# Output()

# %%
ratings
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
movie_id = 1

# %%
similar_users = ratings[(ratings["movieId"] == movie_id) & (ratings["rating"] == 5)]["userId"].unique()

# %%
similar_user_reccs = ratings[(ratings["userId"]. isin(similar_users)) & (ratings["rating"] == 5)]["movieId"]

# %%
similar_users
# Out:
# array([ 31,  40,  43,  46,  57,  63,  71,  96, 145, 151, 166, 171, 177,
#        201, 206, 220, 229, 234, 240, 247, 269, 270, 273, 275, 304, 328,
#        341, 347, 353, 357, 364, 367, 380, 389, 396, 411, 448, 451, 453,
#        456, 471, 533, 559, 573, 584, 587, 610])

# %%
similar_user_reccs
# Out:
# 4879           1
# 4890         377
# 4891         588
# 4894         648
# 4895         733
#            ...
# 100814    158238
# 100829    164179
# 100832    168248
# 100833    168250
# 100834    168252
# Name: movieId, Length: 2067, dtype: int64

# %%
similar_user_reccs = similar_user_reccs.value_counts() / len(similar_users)

similar_user_reccs = similar_user_reccs[similar_user_reccs > 0.1]

# %%
similar_user_reccs
# Out:
# movieId
# 1       1.000000
# 296     0.404255
# 260     0.340426
# 1198    0.276596
# 593     0.276596
#           ...
# 380     0.106383
# 62      0.106383
# 17      0.106383
# 1201    0.106383
# 899     0.106383
# Name: count, Length: 76, dtype: float64

# %%
all_users = ratings[(ratings["movieId"].isin(similar_user_reccs.index)) & (ratings["rating"] == 5)]
all_user_recs = all_users["movieId"].value_counts() / len(all_users["userId"].unique())

# %%
rec_percentages = pd.concat([similar_user_reccs, all_user_recs], axis=1)
rec_percentages.columns = ["similar", "all"]
rec_percentages
# Out:
#           similar       all
# movieId
# 1        1.000000  0.096708
# 296      0.404255  0.253086
# 260      0.340426  0.213992
# 1198     0.276596  0.141975
# 593      0.276596  0.189300
# ...           ...       ...
# 380      0.106383  0.049383
# 62       0.106383  0.041152
# 17       0.106383  0.039095
# 1201     0.106383  0.049383
# 899      0.106383  0.028807
#
# [76 rows x 2 columns]

# %%
rec_percentages["score"] = rec_percentages["similar"] / rec_percentages["all"]

# %%
rec_percentages = rec_percentages.sort_values("score", ascending = False)
rec_percentages
# Out:
#           similar       all      score
# movieId
# 1        1.000000  0.096708  10.340426
# 661      0.106383  0.016461   6.462766
# 3114     0.212766  0.039095   5.442329
# 3175     0.127660  0.024691   5.170213
# 2716     0.212766  0.043210   4.924012
# ...           ...       ...        ...
# 2858     0.127660  0.133745   0.954501
# 608      0.106383  0.117284   0.907055
# 527      0.148936  0.189300   0.786772
# 2571     0.170213  0.224280   0.758930
# 318      0.234043  0.314815   0.743429
#
# [76 rows x 3 columns]

# %%
rec_percentages.head(10).merge(movies, left_index=True, right_on="movieId")
# Out:
#        similar       all      score  movieId  \
# 0     1.000000  0.096708  10.340426        1
# 551   0.106383  0.016461   6.462766      661
# 2355  0.212766  0.039095   5.442329     3114
# 2393  0.127660  0.024691   5.170213     3175
# 2038  0.212766  0.043210   4.924012     2716
# 436   0.148936  0.030864   4.825532      500
# 7355  0.127660  0.028807   4.431611    78499
# 32    0.212766  0.055556   3.829787       34
# 681   0.106383  0.028807   3.693009      899
# 138   0.170213  0.047325   3.596670      165
#
#                                            title  \
# 0                               Toy Story (1995)
# 551             James and the Giant Peach (1996)
# 2355                          Toy Story 2 (1999)
# 2393                         Galaxy Quest (1999)
# 2038  Ghostbusters (a.k.a. Ghost Busters) (1984)
# 436                        Mrs. Doubtfire (1993)
# 7355                          Toy Story 3 (2010)
# 32                                   Babe (1995)
# 681                   Singin' in the Rain (1952)
# 138            Die Hard: With a Vengeance (1995)
#
#                                                 genres  \
# 0          Adventure|Animation|Children|Comedy|Fantasy
# 551       Adventure|Animation|Children|Fantasy|Musical
# 2355       Adventure|Animation|Children|Comedy|Fantasy
# 2393                           Adventure|Comedy|Sci-Fi
# 2038                              Action|Comedy|Sci-Fi
# 436                                       Comedy|Drama
# 7355  Adventure|Animation|Children|Comedy|Fantasy|IMAX
# 32                                      Children|Drama
# 681                             Comedy|Musical|Romance
# 138                              Action|Crime|Thriller
#
#                               clean_title  \
# 0                          Toy Story 1995
# 551        James and the Giant Peach 1996
# 2355                     Toy Story 2 1999
# 2393                    Galaxy Quest 1999
# 2038  Ghostbusters aka Ghost Busters 1984
# 436                    Mrs Doubtfire 1993
# 7355                     Toy Story 3 2010
# 32                              Babe 1995
# 681               Singin in the Rain 1952
# 138        Die Hard With a Vengeance 1995
#
#                                           genres_clean  \
# 0          Adventure Animation Children Comedy Fantasy
# 551       Adventure Animation Children Fantasy Musical
# 2355       Adventure Animation Children Comedy Fantasy
# 2393                           Adventure Comedy Sci-Fi
# 2038                              Action Comedy Sci-Fi
# 436                                       Comedy Drama
# 7355  Adventure Animation Children Comedy Fantasy IMAX
# 32                                      Children Drama
# 681                             Comedy Musical Romance
# 138                              Action Crime Thriller
#
#                                                features
# 0     Toy Story 1995 Adventure Animation Children Co...
# 551   James and the Giant Peach 1996 Adventure Anima...
# 2355  Toy Story 2 1999 Adventure Animation Children ...
# 2393          Galaxy Quest 1999 Adventure Comedy Sci-Fi
# 2038  Ghostbusters aka Ghost Busters 1984 Action Com...
# 436                     Mrs Doubtfire 1993 Comedy Drama
# 7355  Toy Story 3 2010 Adventure Animation Children ...
# 32                             Babe 1995 Children Drama
# 681      Singin in the Rain 1952 Comedy Musical Romance
# 138   Die Hard With a Vengeance 1995 Action Crime Th...

# %%
def find_similar_movies(movie_id):
    similar_users = ratings[(ratings["movieId"] == movie_id) & (ratings["rating"] > 4)]["userId"].unique()
    similar_user_recs = ratings[(ratings["userId"].isin(similar_users)) & (ratings["rating"] > 4)]["movieId"]
    similar_user_recs = similar_user_recs.value_counts() / len(similar_users)

    similar_user_recs = similar_user_recs[similar_user_recs > .10]
    all_users = ratings[(ratings["movieId"].isin(similar_user_recs.index)) & (ratings["rating"] > 4)]
    all_user_recs = all_users["movieId"].value_counts() / len(all_users["userId"].unique())
    rec_percentages = pd.concat([similar_user_recs, all_user_recs], axis=1)
    rec_percentages.columns = ["similar", "all"]

    rec_percentages["score"] = rec_percentages["similar"] / rec_percentages["all"]
    rec_percentages = rec_percentages.sort_values("score", ascending=False)
    return rec_percentages.head(10).merge(movies, left_index=True, right_on="movieId")[["score", "title", "genres"]]

# %%
movie_name_input = widgets.Text(
    value='',
    description='Movie Title:',
    disabled=False
)
recommendation_list = widgets.Output()

def on_type(data):
    with recommendation_list:
        recommendation_list.clear_output()
        title = data["new"]
        if title.strip() != "":   # avoid running on empty input
            results = title_search(title)
            if not results.empty:
                movie_id = results.iloc[0]["movieId"]
                display(find_similar_movies(movie_id))
            else:
                display("No results found.")

movie_name_input.observe(on_type, names='value')

display(movie_name_input, recommendation_list)
# Out:
# Text(value='', description='Movie Title:')
# Output()
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['score'].plot(kind='hist', bins=20, title='score')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_1['score'].plot(kind='line', figsize=(8, 4), title='score')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['score']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'score'}, axis=1)
#               .sort_values('score', ascending=True))
#   xs = counted['score']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_2.sort_values('score', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('score')
# _ = plt.ylabel('count()')
